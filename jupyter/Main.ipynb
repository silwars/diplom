# %%
# Cell 1: Импорт, параметры и выбираемые заголовки
import pandas as pd
import numpy as np
from itertools import combinations
from collections import defaultdict
from datetime import timedelta
import csv
from multiprocessing import Pool, cpu_count
import time

print("[Init] Libraries imported.")

# Window parameters
window_size = timedelta(minutes=30)
slide_size  = timedelta(minutes=15)
print(f"[Init] Window size: {window_size}, Slide size: {slide_size}")

# Discretization specification
BINNING_SPEC = {
    'Total Fwd Packets': ('uniform', 5),
    'Total Backward Packets': ('uniform', 5),
    'Total Length of Fwd Packets': ('uniform', 5),
    'Total Length of Bwd Packets': ('uniform', 5),
    'Active Mean': ('uniform', 5),
    'Idle Mean': ('uniform', 5),
    'Flow Duration': ('uniform', 5)
}

# Параметры алгоритма
MIN_SUPPORT = 10
MIN_CONF    = 0.9
ALPHA       = 3
print(f"[Init] MIN_SUPPORT={MIN_SUPPORT}, MIN_CONF={MIN_CONF}, ALPHA={ALPHA}")

# Группы для MDFP
FEATURE_GROUPS = {
    'network': ['Destination IP','Destination Port','FIN Flag Count','SYN Flag Count',
                'RST Flag Count','PSH Flag Count','ACK Flag Count'],
    'temporal': ['Timestamp','Flow Duration'],
    'traffic': ['Total Fwd Packets','Total Backward Packets',
                'Total Length of Fwd Packets','Total Length of Bwd Packets',
                'Active Mean','Idle Mean']
}
PRIMARY_FEATURES = set(f for grp in FEATURE_GROUPS.values() for f in grp)
print(f"[Init] PRIMARY_FEATURES count: {len(PRIMARY_FEATURES)}")


SELECTED_COLS = ['Total Fwd Packets','Total Backward Packets',
                'Total Length of Fwd Packets','Total Length of Bwd Packets',
                'Active Mean','Idle Mean', 'Flow Duration', 'Destination IP','Destination Port','FIN Flag Count','SYN Flag Count',
                'RST Flag Count','PSH Flag Count','ACK Flag Count'
]

# Флаги для отключения спама принами
VERBOSE_MDFP   = False
MDFP_PRINTED   = False
# Out:
# [Init] Libraries imported.
# [Init] Window size: 0:30:00, Slide size: 0:15:00
# [Init] MIN_SUPPORT=10, MIN_CONF=0.9, ALPHA=3
# [Init] PRIMARY_FEATURES count: 15

# %%
# Cell 2: Загрузка и обработка датасета

path = r'C:\Users\Гребенников Матвей\Desktop\Диплом\Диплом\Code\diplom-project\diplom\test\result\Date\Friday-WorkingHours-Afternoon-DDos.pcap_ISCX_sampled_v4.csv'
df = pd.read_csv(path, low_memory=False)
print(f"[Load] Read DataFrame from {path}, shape: {df.shape}")

df['Timestamp'] = pd.to_datetime(df['Timestamp'])
print("[Load] Converted 'Timestamp' to datetime.")
df.sort_values('Timestamp', inplace=True)
print("[Load] Sorted DataFrame by Timestamp.")
df.reset_index(drop=True, inplace=True)
print("[Load] Reset DataFrame index.")
# Out:
# [Load] Read DataFrame from C:\Users\Гребенников Матвей\Desktop\Диплом\Диплом\Code\diplom-project\diplom\test\result\Date\Friday-WorkingHours-Afternoon-DDos.pcap_ISCX_sampled_v4.csv, shape: (100000, 84)
# [Load] Converted 'Timestamp' to datetime.
# [Load] Sorted DataFrame by Timestamp.
# [Load] Reset DataFrame index.

# %%
# Cell 3: Generate and Encode Transactions (с метками bin0…binN вместо интервалов)

def discretize_columns(df_in, spec, cols):
    """
    Оставляем только Timestamp и указанные cols, 
    дискретизируем с uniform/quantile и метками bin0, bin1, … bin{N-1}
    """
    df2 = df_in[['Timestamp'] + cols].copy()
    for col, (method, bins) in spec.items():
        if col not in df2 or col not in cols:
            continue
        arr = df2[col].astype(float)
        # формируем метки bin0…bin{bins-1}
        labels = [f"bin{i}" for i in range(bins)]
        if method == 'quantile':
            binned = pd.qcut(arr, q=bins, labels=labels, duplicates='drop')
        else:  # uniform
            binned = pd.cut(arr, bins=bins, labels=labels)
        df2[col] = binned.astype(str).astype('category')
    return df2

# Build string transactions
str_trans = []
df_disc = discretize_columns(df, BINNING_SPEC, SELECTED_COLS)
print(f"[Trans] Discretized selected columns, shape: {df_disc.shape}")
for _, row in df_disc.iterrows():
    tr = []
    for col in SELECTED_COLS:
        val = row[col]
        # фильтруем нулевые флаги, если нужно
        if 'flag count' in col.lower() and str(val).startswith('0'):
            continue
        tr.append(f"{col}:{val}")   # e.g. "Active Mean:bin2"
    str_trans.append(tr)
print(f"[Trans] Built string transactions, count: {len(str_trans)}")

# Encode to integer IDs
all_items = sorted({it for tr in str_trans for it in tr})
item2id = {it:i for i,it in enumerate(all_items)}
id2item = {i:it for it,i in item2id.items()}
print(f"[Trans] Unique items: {len(all_items)}")
# Global integer transactions
global_trans = [[item2id[it] for it in tr] for tr in str_trans]
print(f"[Trans] Encoded global transactions, count: {len(global_trans)}")


# Function for windowed transactions (аналогично, с метками binX)
def make_transactions_ids(df_window):
    dfw = discretize_columns(df_window, BINNING_SPEC, SELECTED_COLS)
    trans = []
    for _, row in dfw.iterrows():
        tr = []
        for col in SELECTED_COLS:
            if 'flag count' in col.lower() and str(row[col]).startswith('0'):
                continue
            item = f"{col}:{row[col]}"   # e.g. "Active Mean:bin4"
            if item in item2id:
                tr.append(item2id[item])
        trans.append(tr)
    return trans

print("[Trans] Prepared make_transactions_ids function.")
# Out:
# [Trans] Discretized selected columns, shape: (100000, 15)
# [Trans] Built string transactions, count: 100000
# [Trans] Unique items: 21889
# [Trans] Encoded global transactions, count: 100000
# [Trans] Prepared make_transactions_ids function.

# %%
# Cell 4: COFI-Tree 
class COFINode:
    __slots__ = ('item','count','parent','children','node_link')
    def __init__(self, item, parent):
        self.item = item
        self.count = 1
        self.parent = parent
        self.children = {}
        self.node_link = None
def create_cofi_tree(transactions, min_sup):
    freq = defaultdict(int)
    for tr in transactions:
        for it in tr:
            freq[it] += 1
    freq = {it:c for it,c in freq.items() if c>=min_sup}
    if not freq:
        return None, None
    header = {it:[freq[it], None, None] for it in freq}
    root = COFINode(None, None)
    for tr in transactions:
        flt = [it for it in tr if it in freq]
        flt.sort(key=lambda x: freq[x], reverse=True)
        node = root
        for it in flt:
            if it in node.children:
                child = node.children[it]
                child.count += 1
            else:
                child = COFINode(it, node)
                node.children[it] = child
                if header[it][1] is None:
                    header[it][1] = child
                    header[it][2] = child
                else:
                    header[it][2].node_link = child
                    header[it][2] = child
            node = child
    return root, header

# %%
# Cell 5: Оптимизированный COFI Mining 

from multiprocessing.dummy import Pool  
from multiprocessing import cpu_count
from collections import defaultdict

print("[COFI] Ready to mine prefixes (fully optimized).")

def find_cofi_prefixes(item, header):
    paths = {}
    node = header[item][1]
    while node:
        cnt = node.count
        prefix = []
        p = node.parent
        while p and p.item is not None:
            prefix.append(p.item)
            p = p.parent
        if prefix:
            paths[frozenset(prefix)] = paths.get(frozenset(prefix), 0) + cnt
        node = node.node_link
    return paths

def iterate_node_links(item, header):
    node = header[item][1]
    while node:
        yield node
        node = node.node_link

def build_conditional_cofi_tree(base, header, min_sup):
    
    freq = defaultdict(int)
    conditional_paths = []
    for node in iterate_node_links(base, header):
        path = []
        p = node.parent
        while p and p.item is not None:
            path.append(p.item)
            p = p.parent
        if path:
            conditional_paths.append((path, node.count))
            for it in path:
                freq[it] += node.count

    # 2) Filter infrequent items
    freq = {it:c for it,c in freq.items() if c >= min_sup}
    if not freq:
        return None, None

    # 3) Initialize new header and root
    cond_header = {it:[freq[it], None, None] for it in freq}
    root = COFINode(None, None)

    # 4) Insert each conditional path into the new COFI-tree
    for path, cnt in conditional_paths:
        flt = [it for it in path if it in freq]
        if not flt: continue
        flt.sort(key=lambda x: freq[x], reverse=True)
        node = root
        for it in flt:
            if it in node.children:
                child = node.children[it]
                child.count += cnt
            else:
                child = COFINode(it, node)
                child.count = cnt
                node.children[it] = child
                # back-pointer insertion
                if cond_header[it][1] is None:
                    cond_header[it][1] = child
                    cond_header[it][2] = child
                else:
                    cond_header[it][2].node_link = child
                    cond_header[it][2] = child
            node = child

    return root, cond_header

def rec_cofi(root, header, min_sup, prefix, patterns, max_depth, base, order):
    if len(prefix) >= max_depth:
        return
    for it, (sup, _, _) in sorted(header.items(), key=lambda x: x[1][0]):
        if it <= base or order[it] <= order[base]:
            continue
        newp = prefix | {it}
        patterns[frozenset(newp)] = sup
        # build and mine conditional tree recursively
        cond_root, cond_hdr = build_conditional_cofi_tree(it, header, min_sup)
        if cond_hdr:
            rec_cofi(cond_root, cond_hdr, min_sup, newp, patterns, max_depth, it, order)

def mine_cofi_base(args):
    base, root, header, min_sup, max_depth, order = args
    print(f"[COFI-base] Start base {base}")
    patterns = {frozenset([base]): header[base][0]}

    # Пропуск по минимальной поддержке
    total_support = sum(node.count for node in iterate_node_links(base, header))
    if total_support < min_sup:
        print(f"[COFI-base] Base {base}: conditional support {total_support} < {min_sup}, skipping")
        print(f"[COFI-base] Finished base {base}, found {len(patterns)} patterns")
        return patterns

    cond_root, cond_hdr = build_conditional_cofi_tree(base, header, min_sup)
    if cond_hdr:
        rec_cofi(cond_root, cond_hdr, min_sup, {base}, patterns, max_depth, base, order)

    print(f"[COFI-base] Finished base {base}, found {len(patterns)} patterns")
    return patterns

# Глобальный COFI
root_c, hdr_c = create_cofi_tree(global_trans, MIN_SUPPORT)
if hdr_c:
    print(f"[COFI] Built global tree: {len(hdr_c)} frequent items")
    bases = sorted(hdr_c)
    order = {b:i for i,b in enumerate(bases)}
    args = [(b, root_c, hdr_c, MIN_SUPPORT, 4, order) for b in bases]
    print(f"[COFI] Mining {len(bases)} base elements via ThreadPool...")
    patterns_global = {}
    with Pool(min(cpu_count(), len(bases))) as pool:
        for part in pool.map(mine_cofi_base, args):
            patterns_global.update(part)
    valid_global = set().union(*patterns_global.keys())
    print(f"[COFI] Global mining done: {len(patterns_global)} patterns, {len(valid_global)} valid elements")
else:
    print(f"[COFI] No frequent items >= MIN_SUPPORT={MIN_SUPPORT}")
# Out:
# [COFI] Ready to mine prefixes (fully optimized).
# [COFI] Built global tree: 385 frequent items
# [COFI] Mining 385 base elements via ThreadPool...
# [COFI-base] Start base 0
# [COFI-base] Finished base 0, found 25 patterns
# [COFI-base] Start base 1
# [COFI-base] Finished base 1, found 1 patterns
# [COFI-base] Start base 5
# [COFI-base] Finished base 5, found 21 patterns
# [COFI-base] Start base 31
# [COFI-base] Finished base 31, found 46 patterns
# [COFI-base] Start base 33
# [COFI-base] Finished base 33, found 32 patterns
# [COFI-base] Start base 39
# [COFI-base] Finished base 39, found 32 patterns
# [COFI-base] Start base 41
# [COFI-base] Finished base 41, found 32 patterns
# [COFI-base] Start base 50
# [COFI-base] Finished base 50, found 18 patterns
# [COFI-base] Start base 70
# [COFI-base] Finished base 70, found 25 patterns
# [COFI-base] Start base 83
# [COFI-base] Finished base 83, found 13 patterns
# [COFI-base] Start base 100
# [COFI-base] Finished base 100, found 24 patterns
# [COFI-base] Start base 108
# [COFI-base] Finished base 108, found 13 patterns
# [COFI-base] Start base 128
# [COFI-base] Finished base 128, found 20 patterns
# [COFI-base] Start base 144
# [COFI-base] Finished base 144, found 20 patterns
# [COFI-base] Start base 153
# [COFI-base] Finished base 153, found 43 patterns
# [COFI-base] Start base 167
# [COFI-base] Finished base 167, found 13 patterns
# [COFI-base] Start base 170
# [COFI-base] Finished base 170, found 48 patterns
# [COFI-base] Start base 174
# [COFI-base] Finished base 174, found 19 patterns
# [COFI-base] Start base 182
# [COFI-base] Finished base 182, found 32 patterns
# [COFI-base] Start base 198
# [COFI-base] Finished base 198, found 14 patterns
# [COFI-base] Start base 200
# [COFI-base] Finished base 200, found 31 patterns
# [COFI-base] Start base 219
# [COFI-base] Finished base 219, found 21 patterns
# [COFI-base] Start base 224
# [COFI-base] Finished base 224, found 46 patterns
# [COFI-base] Start base 230
# [COFI-base] Finished base 230, found 14 patterns
# [COFI-base] Start base 236
# [COFI-base] Finished base 236, found 55 patterns
# [COFI-base] Start base 237
# [COFI-base] Finished base 237, found 32 patterns
# [COFI-base] Start base 238
# [COFI-base] Finished base 238, found 32 patterns
# [COFI-base] Start base 247
# [COFI-base] Finished base 247, found 21 patterns
# [COFI-base] Start base 248
# [COFI-base] Finished base 248, found 21 patterns
# [COFI-base] Start base 253
# [COFI-base] Finished base 253, found 14 patterns
# [COFI-base] Start base 254
# [COFI-base] Finished base 254, found 14 patterns
# [COFI-base] Start base 256
# [COFI-base] Finished base 256, found 21 patterns
# [COFI-base] Start base 259
# [COFI-base] Finished base 259, found 13 patterns
# [COFI-base] Start base 264
# [COFI-base] Finished base 264, found 14 patterns
# [COFI-base] Start base 303
# [COFI-base] Finished base 303, found 13 patterns
# [COFI-base] Start base 309
# [COFI-base] Finished base 309, found 31 patterns
# [COFI-base] Start base 310
# [COFI-base] Finished base 310, found 14 patterns
# [COFI-base] Start base 313
# [COFI-base] Finished base 313, found 13 patterns
# [COFI-base] Start base 323
# [COFI-base] Finished base 323, found 16 patterns
# [COFI-base] Start base 325
# [COFI-base] Finished base 325, found 14 patterns
# [COFI-base] Start base 327
# [COFI-base] Start base 329
# [COFI-base] Finished base 329, found 14 patterns
# [COFI-base] Start base 331
# [COFI-base] Finished base 331, found 14 patterns
# [COFI-base] Start base 343
# [COFI-base] Finished base 343, found 14 patterns
# [COFI-base] Start base 352
# [COFI-base] Finished base 352, found 21 patterns
# [COFI-base] Start base 377
# [COFI-base] Finished base 377, found 19 patterns
# [COFI-base] Start base 387
# [COFI-base] Finished base 387, found 32 patterns
# [COFI-base] Start base 400
# [COFI-base] Finished base 400, found 22 patterns
# [COFI-base] Start base 401
# [COFI-base] Finished base 401, found 13 patterns
# [COFI-base] Start base 407
# [COFI-base] Finished base 407, found 13 patterns
# [COFI-base] Start base 411
# [COFI-base] Finished base 411, found 12 patterns
# [COFI-base] Start base 425
# [COFI-base] Finished base 425, found 21 patterns
# [COFI-base] Start base 434
# [COFI-base] Finished base 434, found 25 patterns
# [COFI-base] Start base 447
# [COFI-base] Finished base 447, found 31 patterns
# [COFI-base] Start base 449
# [COFI-base] Finished base 449, found 12 patterns
# [COFI-base] Start base 450
# [COFI-base] Finished base 450, found 44 patterns
# [COFI-base] Start base 454
# [COFI-base] Finished base 454, found 14 patterns
# [COFI-base] Start base 460
# [COFI-base] Finished base 460, found 40 patterns
# [COFI-base] Start base 461
# [COFI-base] Finished base 461, found 66 patterns
# [COFI-base] Start base 462
# [COFI-base] Finished base 462, found 33 patterns
# [COFI-base] Start base 464
# [COFI-base] Finished base 464, found 40 patterns
# [COFI-base] Start base 465
# [COFI-base] Finished base 465, found 40 patterns
# [COFI-base] Start base 466
# [COFI-base] Finished base 466, found 14 patterns
# [COFI-base] Start base 467
# [COFI-base] Finished base 467, found 38 patterns
# [COFI-base] Start base 477
# [COFI-base] Finished base 477, found 21 patterns
# [COFI-base] Start base 508
# [COFI-base] Finished base 508, found 26 patterns
# [COFI-base] Start base 510
# [COFI-base] Finished base 510, found 33 patterns
# [COFI-base] Start base 513
# [COFI-base] Finished base 513, found 12 patterns
# [COFI-base] Start base 516
# [COFI-base] Finished base 516, found 39 patterns
# [COFI-base] Start base 519
# [COFI-base] Finished base 519, found 67 patterns
# [COFI-base] Start base 520
# [COFI-base] Finished base 520, found 78 patterns
# [COFI-base] Start base 521
# [COFI-base] Start base 528
# [COFI-base] Finished base 528, found 76 patterns
# [COFI-base] Start base 533
# [COFI-base] Finished base 533, found 18 patterns
# [COFI-base] Start base 534
# [COFI-base] Finished base 534, found 18 patterns
# [COFI-base] Start base 536
# [COFI-base] Finished base 536, found 83 patterns
# [COFI-base] Start base 539
# [COFI-base] Finished base 539, found 32 patterns
# [COFI-base] Start base 542
# [COFI-base] Finished base 542, found 18 patterns
# [COFI-base] Start base 545
# [COFI-base] Finished base 545, found 32 patterns
# [COFI-base] Start base 547
# [COFI-base] Finished base 547, found 11 patterns
# [COFI-base] Start base 548
# [COFI-base] Finished base 548, found 18 patterns
# [COFI-base] Start base 551
# [COFI-base] Finished base 551, found 12 patterns
# [COFI-base] Start base 552
# [COFI-base] Finished base 552, found 18 patterns
# [COFI-base] Start base 554
# [COFI-base] Finished base 554, found 59 patterns
# [COFI-base] Start base 559
# [COFI-base] Finished base 559, found 107 patterns
# [COFI-base] Start base 560
# [COFI-base] Finished base 560, found 82 patterns
# [COFI-base] Start base 561
# [COFI-base] Finished base 561, found 18 patterns
# [COFI-base] Start base 562
# [COFI-base] Finished base 562, found 50 patterns
# [COFI-base] Start base 567
# [COFI-base] Finished base 567, found 80 patterns
# [COFI-base] Start base 569
# [COFI-base] Finished base 521, found 19 patterns
# [COFI-base] Start base 523
# [COFI-base] Finished base 523, found 18 patterns
# [COFI-base] Start base 524
# [COFI-base] Finished base 524, found 18 patterns
# [COFI-base] Start base 526
# [COFI-base] Finished base 526, found 19 patterns
# [COFI-base] Start base 527
# [COFI-base] Finished base 527, found 51 patterns
# [COFI-base] Start base 577
# [COFI-base] Finished base 577, found 12 patterns
# [COFI-base] Start base 581
# [COFI-base] Finished base 581, found 82 patterns
# [COFI-base] Start base 582
# [COFI-base] Finished base 582, found 12 patterns
# [COFI-base] Start base 583
# [COFI-base] Finished base 583, found 39 patterns
# [COFI-base] Start base 584
# [COFI-base] Finished base 584, found 19 patterns
# [COFI-base] Start base 590
# [COFI-base] Finished base 590, found 91 patterns
# [COFI-base] Start base 596
# [COFI-base] Finished base 596, found 39 patterns
# [COFI-base] Start base 599
# [COFI-base] Finished base 599, found 52 patterns
# [COFI-base] Start base 601
# [COFI-base] Finished base 601, found 40 patterns
# [COFI-base] Start base 602
# [COFI-base] Finished base 602, found 76 patterns
# [COFI-base] Start base 603
# [COFI-base] Finished base 603, found 12 patterns
# [COFI-base] Start base 605
# [COFI-base] Finished base 605, found 32 patterns
# [COFI-base] Start base 608
# [COFI-base] Finished base 608, found 12 patterns
# [COFI-base] Start base 610
# [COFI-base] Finished base 610, found 47 patterns
# [COFI-base] Start base 615
# [COFI-base] Finished base 615, found 12 patterns
# [COFI-base] Start base 618
# [COFI-base] Finished base 618, found 73 patterns
# [COFI-base] Start base 622
# [COFI-base] Finished base 622, found 26 patterns
# [COFI-base] Start base 631
# [COFI-base] Finished base 631, found 18 patterns
# [COFI-base] Start base 635
# [COFI-base] Finished base 635, found 18 patterns
# [COFI-base] Start base 637
# [COFI-base] Finished base 637, found 12 patterns
# [COFI-base] Start base 639
# [COFI-base] Finished base 639, found 18 patterns
# [COFI-base] Start base 640
# [COFI-base] Finished base 569, found 95 patterns
# [COFI-base] Start base 570
# [COFI-base] Finished base 570, found 34 patterns
# [COFI-base] Start base 572
# [COFI-base] Finished base 572, found 12 patterns
# [COFI-base] Start base 574
# [COFI-base] Finished base 574, found 67 patterns
# [COFI-base] Start base 701
# [COFI-base] Finished base 701, found 35 patterns
# [COFI-base] Start base 702
# [COFI-base] Finished base 702, found 14 patterns
# [COFI-base] Start base 706
# [COFI-base] Finished base 706, found 14 patterns
# [COFI-base] Start base 709
# [COFI-base] Finished base 709, found 55 patterns
# [COFI-base] Start base 715
# [COFI-base] Finished base 715, found 21 patterns
# [COFI-base] Start base 719
# [COFI-base] Finished base 719, found 26 patterns
# [COFI-base] Start base 723
# [COFI-base] Finished base 723, found 39 patterns
# [COFI-base] Start base 726
# [COFI-base] Finished base 726, found 14 patterns
# [COFI-base] Start base 736
# [COFI-base] Finished base 736, found 14 patterns
# [COFI-base] Start base 749
# [COFI-base] Finished base 749, found 32 patterns
# [COFI-base] Start base 776
# [COFI-base] Finished base 776, found 46 patterns
# [COFI-base] Start base 777
# [COFI-base] Finished base 777, found 38 patterns
# [COFI-base] Start base 794
# [COFI-base] Finished base 794, found 13 patterns
# [COFI-base] Start base 804
# [COFI-base] Finished base 804, found 12 patterns
# [COFI-base] Start base 807
# [COFI-base] Finished base 807, found 14 patterns
# [COFI-base] Start base 813
# [COFI-base] Finished base 813, found 21 patterns
# [COFI-base] Start base 817
# [COFI-base] Finished base 817, found 34 patterns
# [COFI-base] Start base 818
# [COFI-base] Finished base 818, found 20 patterns
# [COFI-base] Start base 819
# [COFI-base] Finished base 819, found 27 patterns
# [COFI-base] Start base 820
# [COFI-base] Finished base 820, found 27 patterns
# [COFI-base] Start base 821
# [COFI-base] Finished base 821, found 15 patterns
# [COFI-base] Start base 822
# [COFI-base] Finished base 822, found 18 patterns
# [COFI-base] Start base 823
# [COFI-base] Finished base 823, found 20 patterns
# [COFI-base] Start base 824
# [COFI-base] Finished base 824, found 38 patterns
# [COFI-base] Start base 825
# [COFI-base] Finished base 825, found 35 patterns
# [COFI-base] Start base 826
# [COFI-base] Finished base 826, found 50 patterns
# [COFI-base] Start base 827
# [COFI-base] Finished base 827, found 27 patterns
# [COFI-base] Start base 828
# [COFI-base] Start base 830
# [COFI-base] Finished base 830, found 27 patterns
# [COFI-base] Start base 831
# [COFI-base] Finished base 831, found 27 patterns
# [COFI-base] Start base 832
# [COFI-base] Finished base 832, found 33 patterns
# [COFI-base] Start base 838
# [COFI-base] Finished base 838, found 33 patterns
# [COFI-base] Start base 840
# [COFI-base] Finished base 840, found 13 patterns
# [COFI-base] Start base 843
# [COFI-base] Finished base 843, found 12 patterns
# [COFI-base] Start base 849
# [COFI-base] Finished base 849, found 43 patterns
# [COFI-base] Start base 854
# [COFI-base] Finished base 854, found 14 patterns
# [COFI-base] Start base 855
# [COFI-base] Finished base 855, found 13 patterns
# [COFI-base] Start base 857
# [COFI-base] Finished base 857, found 55 patterns
# [COFI-base] Start base 866
# [COFI-base] Finished base 866, found 14 patterns
# [COFI-base] Start base 868
# [COFI-base] Finished base 868, found 14 patterns
# [COFI-base] Start base 870
# [COFI-base] Finished base 870, found 33 patterns
# [COFI-base] Start base 874
# [COFI-base] Finished base 874, found 14 patterns
# [COFI-base] Start base 886
# [COFI-base] Finished base 886, found 31 patterns
# [COFI-base] Start base 887
# [COFI-base] Finished base 887, found 14 patterns
# [COFI-base] Start base 888
# [COFI-base] Finished base 888, found 21 patterns
# [COFI-base] Start base 894
# [COFI-base] Finished base 894, found 38 patterns
# [COFI-base] Start base 895
# [COFI-base] Finished base 895, found 21 patterns
# [COFI-base] Start base 898
# [COFI-base] Finished base 898, found 43 patterns
# [COFI-base] Start base 901
# [COFI-base] Finished base 901, found 21 patterns
# [COFI-base] Start base 907
# [COFI-base] Finished base 907, found 14 patterns
# [COFI-base] Start base 914
# [COFI-base] Finished base 914, found 14 patterns
# [COFI-base] Start base 925
# [COFI-base] Finished base 925, found 12 patterns
# [COFI-base] Start base 929
# [COFI-base] Finished base 929, found 13 patterns
# [COFI-base] Start base 934
# [COFI-base] Finished base 934, found 15 patterns
# [COFI-base] Start base 937
# [COFI-base] Finished base 937, found 32 patterns
# [COFI-base] Start base 940
# [COFI-base] Finished base 940, found 38 patterns
# [COFI-base] Start base 948
# [COFI-base] Finished base 948, found 32 patterns
# [COFI-base] Start base 949
# [COFI-base] Finished base 949, found 17 patterns
# [COFI-base] Start base 956
# [COFI-base] Finished base 956, found 39 patterns
# [COFI-base] Start base 957
# [COFI-base] Finished base 957, found 14 patterns
# [COFI-base] Start base 966
# [COFI-base] Finished base 966, found 12 patterns
# [COFI-base] Start base 974
# [COFI-base] Finished base 974, found 11 patterns
# [COFI-base] Start base 977
# [COFI-base] Finished base 640, found 20 patterns
# [COFI-base] Start base 642
# [COFI-base] Finished base 642, found 13 patterns
# [COFI-base] Start base 667
# [COFI-base] Finished base 667, found 14 patterns
# [COFI-base] Start base 676
# [COFI-base] Finished base 676, found 14 patterns
# [COFI-base] Start base 680
# [COFI-base] Finished base 680, found 80 patterns
# [COFI-base] Start base 681
# [COFI-base] Finished base 681, found 43 patterns
# [COFI-base] Start base 689
# [COFI-base] Finished base 689, found 13 patterns
# [COFI-base] Start base 978
# [COFI-base] Finished base 978, found 56 patterns
# [COFI-base] Start base 1010
# [COFI-base] Finished base 1010, found 14 patterns
# [COFI-base] Start base 1012
# [COFI-base] Finished base 1012, found 38 patterns
# [COFI-base] Start base 1013
# [COFI-base] Finished base 1013, found 14 patterns
# [COFI-base] Start base 1014
# [COFI-base] Finished base 1014, found 21 patterns
# [COFI-base] Start base 1015
# [COFI-base] Finished base 1015, found 21 patterns
# [COFI-base] Start base 1026
# [COFI-base] Finished base 1026, found 12 patterns
# [COFI-base] Start base 1029
# [COFI-base] Finished base 1029, found 17 patterns
# [COFI-base] Start base 1034
# [COFI-base] Finished base 1034, found 21 patterns
# [COFI-base] Start base 1035
# [COFI-base] Finished base 1035, found 21 patterns
# [COFI-base] Start base 1051
# [COFI-base] Finished base 1051, found 14 patterns
# [COFI-base] Start base 1052
# [COFI-base] Finished base 1052, found 14 patterns
# [COFI-base] Start base 1053
# [COFI-base] Finished base 1053, found 14 patterns
# [COFI-base] Start base 1056
# [COFI-base] Finished base 1056, found 34 patterns
# [COFI-base] Start base 1057
# [COFI-base] Finished base 1057, found 14 patterns
# [COFI-base] Start base 1061
# [COFI-base] Finished base 1061, found 14 patterns
# [COFI-base] Start base 1093
# [COFI-base] Finished base 1093, found 14 patterns
# [COFI-base] Start base 1100
# [COFI-base] Finished base 1100, found 13 patterns
# [COFI-base] Start base 1104
# [COFI-base] Finished base 1104, found 12 patterns
# [COFI-base] Start base 1113
# [COFI-base] Finished base 1113, found 12 patterns
# [COFI-base] Start base 1114
# [COFI-base] Finished base 1114, found 43 patterns
# [COFI-base] Start base 1121
# [COFI-base] Finished base 1121, found 9 patterns
# [COFI-base] Start base 1127
# [COFI-base] Finished base 1127, found 21 patterns
# [COFI-base] Start base 1146
# [COFI-base] Finished base 1146, found 54 patterns
# [COFI-base] Start base 1149
# [COFI-base] Finished base 1149, found 18 patterns
# [COFI-base] Start base 1165
# [COFI-base] Finished base 1165, found 25 patterns
# [COFI-base] Start base 1166
# [COFI-base] Finished base 1166, found 12 patterns
# [COFI-base] Start base 1167
# [COFI-base] Finished base 1167, found 13 patterns
# [COFI-base] Start base 1174
# [COFI-base] Finished base 1174, found 13 patterns
# [COFI-base] Start base 1176
# [COFI-base] Finished base 1176, found 18 patterns
# [COFI-base] Start base 1177
# [COFI-base] Finished base 1177, found 21 patterns
# [COFI-base] Start base 1181
# [COFI-base] Finished base 1181, found 16 patterns
# [COFI-base] Start base 1184
# [COFI-base] Finished base 1184, found 12 patterns
# [COFI-base] Start base 1187
# [COFI-base] Finished base 1187, found 31 patterns
# [COFI-base] Start base 1192
# [COFI-base] Finished base 977, found 99 patterns
# [COFI-base] Start base 1197
# [COFI-base] Finished base 1197, found 15 patterns
# [COFI-base] Start base 1202
# [COFI-base] Finished base 1202, found 12 patterns
# [COFI-base] Start base 1203
# [COFI-base] Finished base 1203, found 15 patterns
# [COFI-base] Start base 1223
# [COFI-base] Finished base 1223, found 38 patterns
# [COFI-base] Start base 1226
# [COFI-base] Finished base 1226, found 32 patterns
# [COFI-base] Start base 1229
# [COFI-base] Finished base 1229, found 43 patterns
# [COFI-base] Start base 1250
# [COFI-base] Finished base 1250, found 13 patterns
# [COFI-base] Start base 1264
# [COFI-base] Finished base 1264, found 12 patterns
# [COFI-base] Start base 1266
# [COFI-base] Finished base 1266, found 43 patterns
# [COFI-base] Start base 1267
# [COFI-base] Finished base 1267, found 32 patterns
# [COFI-base] Start base 1301
# [COFI-base] Finished base 1301, found 32 patterns
# [COFI-base] Start base 1304
# [COFI-base] Finished base 1304, found 13 patterns
# [COFI-base] Start base 1315
# [COFI-base] Finished base 1315, found 32 patterns
# [COFI-base] Start base 1316
# [COFI-base] Finished base 1316, found 51 patterns
# [COFI-base] Start base 1321
# [COFI-base] Finished base 1321, found 32 patterns
# [COFI-base] Start base 1322
# [COFI-base] Finished base 1322, found 46 patterns
# [COFI-base] Start base 1326
# [COFI-base] Finished base 1326, found 51 patterns
# [COFI-base] Start base 1329
# [COFI-base] Finished base 1329, found 13 patterns
# [COFI-base] Start base 1332
# [COFI-base] Finished base 1332, found 88 patterns
# [COFI-base] Start base 1335
# [COFI-base] Finished base 1335, found 51 patterns
# [COFI-base] Start base 1336
# [COFI-base] Finished base 1336, found 68 patterns
# [COFI-base] Start base 1349
# [COFI-base] Finished base 1349, found 13 patterns
# [COFI-base] Start base 1355
# [COFI-base] Finished base 1355, found 12 patterns
# [COFI-base] Start base 1360
# [COFI-base] Finished base 1360, found 33 patterns
# [COFI-base] Start base 1362
# [COFI-base] Finished base 1362, found 26 patterns
# [COFI-base] Start base 1367
# [COFI-base] Finished base 1192, found 13 patterns
# [COFI-base] Start base 1379
# [COFI-base] Finished base 1379, found 13 patterns
# [COFI-base] Start base 1462
# [COFI-base] Finished base 1462, found 13 patterns
# [COFI-base] Start base 1469
# [COFI-base] Finished base 1469, found 14 patterns
# [COFI-base] Start base 1478
# [COFI-base] Finished base 1478, found 48 patterns
# [COFI-base] Start base 1479
# [COFI-base] Finished base 1479, found 39 patterns
# [COFI-base] Start base 1483
# [COFI-base] Finished base 1483, found 14 patterns
# [COFI-base] Start base 1491
# [COFI-base] Finished base 1491, found 12 patterns
# [COFI-base] Start base 1493
# [COFI-base] Finished base 1493, found 13 patterns
# [COFI-base] Start base 1509
# [COFI-base] Finished base 1509, found 13 patterns
# [COFI-base] Start base 1533
# [COFI-base] Finished base 1533, found 38 patterns
# [COFI-base] Start base 1534
# [COFI-base] Finished base 1534, found 14 patterns
# [COFI-base] Start base 1551
# [COFI-base] Finished base 1551, found 14 patterns
# [COFI-base] Start base 1553
# [COFI-base] Finished base 1553, found 21 patterns
# [COFI-base] Start base 1754
# [COFI-base] Finished base 1754, found 13 patterns
# [COFI-base] Start base 1760
# [COFI-base] Finished base 1760, found 34 patterns
# [COFI-base] Start base 1792
# [COFI-base] Finished base 1792, found 12 patterns
# [COFI-base] Start base 1821
# [COFI-base] Finished base 1821, found 21 patterns
# [COFI-base] Start base 1824
# [COFI-base] Finished base 1824, found 17 patterns
# [COFI-base] Start base 1941
# [COFI-base] Finished base 1941, found 46 patterns
# [COFI-base] Start base 1946
# [COFI-base] Finished base 1946, found 15 patterns
# [COFI-base] Start base 1988
# [COFI-base] Finished base 1988, found 31 patterns
# [COFI-base] Start base 2031
# [COFI-base] Finished base 2031, found 21 patterns
# [COFI-base] Start base 2035
# [COFI-base] Finished base 2035, found 14 patterns
# [COFI-base] Start base 2037
# [COFI-base] Finished base 2037, found 32 patterns
# [COFI-base] Start base 2046
# [COFI-base] Finished base 2046, found 14 patterns
# [COFI-base] Start base 2050
# [COFI-base] Finished base 2050, found 21 patterns
# [COFI-base] Start base 2052
# [COFI-base] Finished base 2052, found 21 patterns
# [COFI-base] Start base 2055
# [COFI-base] Finished base 2055, found 21 patterns
# [COFI-base] Start base 2065
# [COFI-base] Finished base 2065, found 14 patterns
# [COFI-base] Start base 2073
# [COFI-base] Finished base 2073, found 13 patterns
# [COFI-base] Start base 2074
# [COFI-base] Finished base 2074, found 13 patterns
# [COFI-base] Start base 2077
# [COFI-base] Finished base 2077, found 33 patterns
# [COFI-base] Start base 2079
# [COFI-base] Finished base 2079, found 21 patterns
# [COFI-base] Start base 2085
# [COFI-base] Finished base 2085, found 32 patterns
# [COFI-base] Start base 2111
# [COFI-base] Finished base 2111, found 11 patterns
# [COFI-base] Start base 2131
# [COFI-base] Finished base 2131, found 14 patterns
# [COFI-base] Start base 2139
# [COFI-base] Finished base 2139, found 13 patterns
# [COFI-base] Start base 2142
# [COFI-base] Finished base 2142, found 38 patterns
# [COFI-base] Start base 2143
# [COFI-base] Finished base 2143, found 14 patterns
# [COFI-base] Start base 2144
# [COFI-base] Finished base 2144, found 15 patterns
# [COFI-base] Start base 2146
# [COFI-base] Finished base 2146, found 38 patterns
# [COFI-base] Start base 2147
# [COFI-base] Finished base 2147, found 14 patterns
# [COFI-base] Start base 2148
# [COFI-base] Finished base 1367, found 33 patterns
# [COFI-base] Start base 1368
# [COFI-base] Finished base 1368, found 32 patterns
# [COFI-base] Start base 1369
# [COFI-base] Finished base 1369, found 40 patterns
# [COFI-base] Start base 2168
# [COFI-base] Finished base 2168, found 62 patterns
# [COFI-base] Start base 2169
# [COFI-base] Finished base 2169, found 21 patterns
# [COFI-base] Start base 2170
# [COFI-base] Finished base 2170, found 21 patterns
# [COFI-base] Start base 2174
# [COFI-base] Finished base 2174, found 43 patterns
# [COFI-base] Start base 2182
# [COFI-base] Finished base 2182, found 21 patterns
# [COFI-base] Start base 2183
# [COFI-base] Finished base 2183, found 21 patterns
# [COFI-base] Start base 2189
# [COFI-base] Finished base 2189, found 26 patterns
# [COFI-base] Start base 2191
# [COFI-base] Finished base 2191, found 25 patterns
# [COFI-base] Start base 2194
# [COFI-base] Finished base 2194, found 66 patterns
# [COFI-base] Start base 2196
# [COFI-base] Finished base 2196, found 33 patterns
# [COFI-base] Start base 2198
# [COFI-base] Finished base 2198, found 31 patterns
# [COFI-base] Start base 2199
# [COFI-base] Finished base 2199, found 32 patterns
# [COFI-base] Start base 2201
# [COFI-base] Finished base 2201, found 38 patterns
# [COFI-base] Start base 2217
# [COFI-base] Finished base 2217, found 53 patterns
# [COFI-base] Start base 2219
# [COFI-base] Finished base 2219, found 14 patterns
# [COFI-base] Start base 2222
# [COFI-base] Finished base 2222, found 48 patterns
# [COFI-base] Start base 2223
# [COFI-base] Finished base 2223, found 19 patterns
# [COFI-base] Start base 2227
# [COFI-base] Finished base 2227, found 48 patterns
# [COFI-base] Start base 2229
# [COFI-base] Finished base 2229, found 12 patterns
# [COFI-base] Start base 2236
# [COFI-base] Finished base 2236, found 14 patterns
# [COFI-base] Start base 2237
# [COFI-base] Finished base 2237, found 14 patterns
# [COFI-base] Start base 2254
# [COFI-base] Finished base 2254, found 32 patterns
# [COFI-base] Start base 2267
# [COFI-base] Finished base 2267, found 14 patterns
# [COFI-base] Start base 2271
# [COFI-base] Finished base 2271, found 14 patterns
# [COFI-base] Start base 2287
# [COFI-base] Finished base 2287, found 12 patterns
# [COFI-base] Start base 2298
# [COFI-base] Finished base 2298, found 13 patterns
# [COFI-base] Start base 2299
# [COFI-base] Finished base 2299, found 20 patterns
# [COFI-base] Start base 2305
# [COFI-base] Finished base 2305, found 24 patterns
# [COFI-base] Start base 2331
# [COFI-base] Finished base 2331, found 14 patterns
# [COFI-base] Start base 2332
# [COFI-base] Finished base 2332, found 14 patterns
# [COFI-base] Start base 2339
# [COFI-base] Finished base 2339, found 14 patterns
# [COFI-base] Start base 2346
# [COFI-base] Finished base 2346, found 14 patterns
# [COFI-base] Start base 2347
# [COFI-base] Finished base 2347, found 14 patterns
# [COFI-base] Start base 2354
# [COFI-base] Finished base 2148, found 30 patterns
# [COFI-base] Start base 2149
# [COFI-base] Finished base 2149, found 20 patterns
# [COFI-base] Start base 2152
# [COFI-base] Finished base 2152, found 38 patterns
# [COFI-base] Start base 2153
# [COFI-base] Finished base 2153, found 29 patterns
# [COFI-base] Start base 2154
# [COFI-base] Finished base 2154, found 16 patterns
# [COFI-base] Start base 2161
# [COFI-base] Finished base 2161, found 13 patterns
# [COFI-base] Start base 2167
# [COFI-base] Finished base 2167, found 64 patterns
# [COFI-base] Start base 2363
# [COFI-base] Finished base 2363, found 14 patterns
# [COFI-base] Start base 2365
# [COFI-base] Finished base 2365, found 32 patterns
# [COFI-base] Start base 2369
# [COFI-base] Finished base 2369, found 14 patterns
# [COFI-base] Start base 2371
# [COFI-base] Finished base 2371, found 14 patterns
# [COFI-base] Start base 2384
# [COFI-base] Finished base 2384, found 38 patterns
# [COFI-base] Start base 2392
# [COFI-base] Finished base 2392, found 43 patterns
# [COFI-base] Start base 2393
# [COFI-base] Finished base 2393, found 38 patterns
# [COFI-base] Start base 2394
# [COFI-base] Finished base 2394, found 14 patterns
# [COFI-base] Start base 2395
# [COFI-base] Finished base 2395, found 30 patterns
# [COFI-base] Start base 2836
# [COFI-base] Finished base 2836, found 39 patterns
# [COFI-base] Start base 2839
# [COFI-base] Finished base 2839, found 13 patterns
# [COFI-base] Start base 2840
# [COFI-base] Finished base 2840, found 13 patterns
# [COFI-base] Start base 2842
# [COFI-base] Finished base 2842, found 13 patterns
# [COFI-base] Start base 2843
# [COFI-base] Finished base 2843, found 27 patterns
# [COFI-base] Start base 4308
# [COFI-base] Finished base 4308, found 20 patterns
# [COFI-base] Start base 4523
# [COFI-base] Finished base 4523, found 20 patterns
# [COFI-base] Start base 6586
# [COFI-base] Finished base 6586, found 75 patterns
# [COFI-base] Start base 8197
# [COFI-base] Finished base 8197, found 70 patterns
# [COFI-base] Start base 9382
# [COFI-base] Finished base 327, found 25 patterns
# [COFI-base] Start base 328
# [COFI-base] Finished base 328, found 14 patterns
# [COFI-base] Start base 9998
# [COFI-base] Finished base 9998, found 12 patterns
# [COFI-base] Start base 12155
# [COFI-base] Finished base 12155, found 26 patterns
# [COFI-base] Start base 12528
# [COFI-base] Finished base 12528, found 13 patterns
# [COFI-base] Start base 21215
# [COFI-base] Finished base 21215, found 26 patterns
# [COFI-base] Start base 21216
# [COFI-base] Finished base 21216, found 36 patterns
# [COFI-base] Start base 21244
# [COFI-base] Finished base 21244, found 20 patterns
# [COFI-base] Start base 21855
# [COFI-base] Finished base 21855, found 13 patterns
# [COFI-base] Start base 21856
# [COFI-base] Finished base 21856, found 7 patterns
# [COFI-base] Start base 21857
# [COFI-base] Finished base 21857, found 50 patterns
# [COFI-base] Start base 21858
# [COFI-base] Finished base 21858, found 65 patterns
# [COFI-base] Start base 21859
# [COFI-base] Finished base 21859, found 34 patterns
# [COFI-base] Start base 21860
# [COFI-base] Finished base 21860, found 55 patterns
# [COFI-base] Start base 21861
# [COFI-base] Finished base 21861, found 5 patterns
# [COFI-base] Start base 21862
# [COFI-base] Finished base 21862, found 16 patterns
# [COFI-base] Start base 21863
# [COFI-base] Finished base 21863, found 25 patterns
# [COFI-base] Start base 21864
# [COFI-base] Finished base 21864, found 25 patterns
# [COFI-base] Start base 21865
# [COFI-base] Finished base 21865, found 25 patterns
# [COFI-base] Start base 21866
# [COFI-base] Finished base 21866, found 8 patterns
# [COFI-base] Start base 21867
# [COFI-base] Finished base 21867, found 11 patterns
# [COFI-base] Start base 21868
# [COFI-base] Finished base 21868, found 7 patterns
# [COFI-base] Start base 21869
# [COFI-base] Finished base 21869, found 2 patterns
# [COFI-base] Start base 21870
# [COFI-base] Finished base 21870, found 6 patterns
# [COFI-base] Start base 21874
# [COFI-base] Finished base 21874, found 1 patterns
# [COFI-base] Start base 21875
# [COFI-base] Finished base 21875, found 4 patterns
# [COFI-base] Start base 21879
# [COFI-base] Finished base 21879, found 2 patterns
# [COFI-base] Start base 21880
# [COFI-base] Finished base 21880, found 2 patterns
# [COFI-base] Start base 21884
# [COFI-base] Finished base 21884, found 1 patterns
# [COFI-base] Start base 21885
# [COFI-base] Finished base 21885, found 1 patterns
# [COFI-base] Finished base 2354, found 21 patterns
# [COFI-base] Start base 2360
# [COFI-base] Finished base 2360, found 14 patterns
# [COFI-base] Finished base 828, found 33 patterns
# [COFI-base] Finished base 9382, found 37 patterns
# [COFI-base] Start base 9388
# [COFI-base] Finished base 9388, found 42 patterns
# [COFI-base] Start base 9535
# [COFI-base] Finished base 9535, found 27 patterns
# [COFI] Global mining done: 10249 patterns, 385 valid elements

# %%
# Cell 6: MDFP-Tree Construction с параллельным подсчётом пар

from collections import defaultdict
from itertools import combinations
from multiprocessing import Pool, cpu_count

# (флаги и класс MDFPNode остаются без изменений)

def _count_pairs_chunk(args):
    chunk, freq = args
    local = defaultdict(lambda: defaultdict(int))
    for tr in chunk:
        flt = [it for it in tr if it in freq]
        # НЕ сортируем — combinations пройдёт по всем парам в любом порядке
        for i,j in combinations(flt,2):
            local[i][j] += 1
            local[j][i] += 1
    return local
class MDFPNode:
    __slots__ = ('item', 'group', 'parent', 'children', 'count', 'link', 'array')
    def __init__(self, item, group, parent):
        self.item     = item
        self.group    = group
        self.parent   = parent
        self.children = {}
        self.count    = 1
        self.link     = None
        self.array    = 0

def create_mdfp_tree(transactions, min_sup):
    """
    1) Считаем одиночные частоты
    2) Фильтруем по min_sup и готовим header
    3) Последовательно считаем pair_sup
    4) Строим дерево
    """
    # --- 1) одиночные частоты + header ---
    freq = defaultdict(int)
    for tr in transactions:
        for it in tr:
            freq[it] += 1
    freq = {it:c for it,c in freq.items() if c >= min_sup}
    if not freq:
        return None, None, {}
    header = {it:[freq[it], None, None, 0] for it in freq}

    # --- 2) последовательный подсчёт пар ---
    pair_sup = defaultdict(lambda: defaultdict(int))
    for tr in transactions:
        # фильтруем сразу по частотам
        flt = [it for it in tr if it in freq]
        # считаем для каждой пары
        for i,j in combinations(flt, 2):
            pair_sup[i][j] += 1
            pair_sup[j][i] += 1

    # --- 3) строим сам MDFP-дерево ---
    root = MDFPNode(None, None, None)
    for tr in transactions:
        flt = [it for it in tr if it in freq]
        if not flt:
            continue
        node = root
        for key in flt:
            if key in node.children:
                child = node.children[key]
                child.count += 1
            else:
                child = MDFPNode(
                    key,
                    next((g for g,v in FEATURE_GROUPS.items()
                          if id2item[key].split(':')[0] in v), None),
                    node
                )
                node.children[key] = child
                # back-pointer
                if header[key][1] is None:
                    header[key][1] = child
                    header[key][2] = child
                else:
                    header[key][2].link = child
                    header[key][2] = child
                header[key][3] += 1
            node = child

    return root, header, pair_sup


# Cell 6b: MDFP Mining Functions

def find_prefix_paths(base, header):
    """
    Из header[base] по ссылкам link собираем все префикс-пути и суммируем их count.
    """
    paths = {}
    node = header[base][1]
    while node:
        cnt = node.count
        prefix = []
        p = node.parent
        while p and p.item is not None:
            prefix.append(p.item)
            p = p.parent
        if prefix:
            paths[frozenset(prefix)] = paths.get(frozenset(prefix), 0) + cnt
        node = node.link
    return paths

def mine_sparse(item, header, pair_sup, transactions, min_sup, k_max=4):
    """
    Разреженная ветвь MDFP: генерируем L1, Lk по pair_sup без дерева.
    """
    patterns = {}
    L1 = [j for j in pair_sup[item] if pair_sup[item][j] >= min_sup]
    for j in L1:
        patterns[frozenset([item, j])] = pair_sup[item][j]
    Lk_1 = [frozenset([item, j]) for j in L1]
    k = 3
    while Lk_1 and k <= k_max:
        Ck = set()
        for prev in Lk_1:
            for j in L1:
                if j not in prev:
                    c = prev | {j}
                    if len(c) == k:
                        Ck.add(c)
        Lk = []
        for c in Ck:
            cnt = sum(1 for tr in transactions if c.issubset(tr))
            if cnt >= min_sup:
                patterns[c] = cnt
                Lk.append(c)
        Lk_1, k = Lk, k+1
    return patterns

def mine_dense_item(item, root, header, min_sup):
    """
    Плотная ветвь MDFP: строим условный набор транзакций и рекурсивно майним.
    """
    patterns = {frozenset([item]): header[item][0]}
    cond = find_prefix_paths(item, header)
    trans = []
    for pth, cnt in cond.items():
        trans += [list(pth)] * cnt
    if trans:
        sub_root, sub_header, _ = create_mdfp_tree(trans, min_sup)
        if sub_header:
            def rec(nr, nh, prefix):
                for it, (s, head, last, link_ct) in sorted(nh.items(), key=lambda x: x[1][0]):
                    newset = prefix | {it}
                    patterns[frozenset(newset)] = s
                    cond2 = find_prefix_paths(it, nh)
                    t2 = []
                    for p2, c2 in cond2.items():
                        t2 += [list(p2)] * c2
                    if t2:
                        sr, sh, _ = create_mdfp_tree(t2, min_sup)
                        if sh:
                            rec(sr, sh, newset)
            rec(sub_root, sub_header, {item})
    return patterns

def mine_mdfp(transactions, min_sup):
    """
    Основная точка входа для майнинга MDFP: строим дерево, 
    разделяем элементы на sparse/dense и собираем все patterns.
    """
    root, header, pair_sup = create_mdfp_tree(transactions, min_sup)
    if not header:
        return {}
    # разделяем на разреженные и плотные
    sparse = [it for it, (sup, head, last, link_ct) in header.items() if head and head.array == 1]
    dense  = [it for it in header if it not in sparse]
    patterns = {}
    for it in sparse:
        patterns.update(mine_sparse(it, header, pair_sup, transactions, min_sup))
    for it in dense:
        patterns.update(mine_dense_item(it, root, header, min_sup))
    return patterns

# %%
# Cell 7: Pattern Filtering and Rule Generation

def filter_closed(patterns):
    closed = {}
    for p, s in patterns.items():
        if not any(len(q) > len(p) and p.issubset(q) and patterns[q] == s
                   for q in patterns):
            closed[p] = s
    print(f"[Filter] Closed patterns count: {len(closed)}")
    return closed

def generate_rules(patterns, min_conf, total_tx):
    rules = []
    for pat, supAB in patterns.items():
        # теперь требуем размер паттерна ≥ 3 (т.е. ≥2 в antecedent + 1 в consequent)
        if len(pat) < 3 or len(pat) > 5:
            continue

        # перебираем r-элементные A, где r от 2 до len(pat)-1
        for r in range(2, len(pat)):
            for A in combinations(pat, r):
                B = set(pat) - set(A)
                if len(B) != 1:
                    continue
                b = next(iter(B))

                # оставляем только A, которые содержат хотя бы один первичный признак
                if not any(id2item[a].split(':')[0] in PRIMARY_FEATURES for a in A):
                    continue

                supA = patterns.get(frozenset(A), 0)
                if supA == 0:
                    continue

                conf = supAB / supA
                if conf < min_conf:
                    continue

                supB = patterns.get(frozenset([b]), supAB)
                lift = conf / (supB / total_tx) if supB > 0 else np.nan

                # фильтруем lift, близкий к 1: |lift − 1| ≤ 0.15
                if abs(lift - 1) <= 0.15:
                    continue

                rules.append((set(A), b, supAB, conf, lift))

    # удаляем избыточные правила
    final = []
    for i, (A, b, s, cf, l) in enumerate(rules):
        if not any(
            i != j and b == b2 and s == s2 and abs(cf - cf2) < 1e-9 and A2.issubset(A)
            for j, (A2, b2, s2, cf2, l2) in enumerate(rules)
        ):
            final.append((A, b, s, cf, l))

    print(f"[Rules] Generated {len(final)} filtered rules")
    return final

# %%
# Cell 8: Sliding Window Loop and CSV Export

import time
import csv

# helper: превращаем "Col:val" → "Col=val" (без _bin)
def format_item(item_str):
    col, val = item_str.split(':', 1)
    return f"{col}={val}"

# Инициализация CSV-файлов
with open('frequent_itemsets_no_label.csv', 'w', newline='') as f:
    csv.writer(f).writerow(['Start','End','Pattern','Support'])
with open('closed_patterns_no_label.csv', 'w', newline='') as f:
    csv.writer(f).writerow(['Start','End','ClosedPattern','Support'])
with open('association_rules_no_label.csv', 'w', newline='') as f:
    csv.writer(f).writerow(['Start','End','Antecedent','Consequent','Support','Confidence','Lift'])
print("[CSV] Initialized CSV files.")

# Генерируем окна
windows = []
cur = df['Timestamp'].min()
end = df['Timestamp'].max()
while cur + window_size <= end:
    windows.append((cur, cur + window_size))
    cur += slide_size
print(f"[Window] Total windows: {len(windows)}")

# Обработка по окнам
for idx, (t0, t1) in enumerate(windows, 1):
    print(f"\n[Window {idx}/{len(windows)}] {t0} -> {t1}")
    df_w = df[(df['Timestamp'] >= t0) & (df['Timestamp'] < t1)]
    trans = make_transactions_ids(df_w)
    print(f"[Window {idx}] Transactions: {len(trans)}")
    filt = [[i for i in tr if i in valid_global] for tr in trans]
    non_empty = sum(1 for tr in filt if tr)
    print(f"[Window {idx}] After filter: {non_empty} non-empty")

    # майнинг MDFP с таймером
    print(f"[Window {idx}] Starting MDFP mining…")
    t_start = time.time()
    mdfp_pats = mine_mdfp(filt, MIN_SUPPORT)
    t_end = time.time()
    print(f"[Window {idx}] MDFP done in {t_end-t_start:.1f}s, patterns: {len(mdfp_pats)}")

    closed = filter_closed(mdfp_pats)
    rules  = generate_rules(closed, MIN_CONF, non_empty)
    print(f"[Window {idx}] Rules: {len(rules)}")

    # Export frequent patterns
    with open('frequent_itemsets_no_label.csv', 'a', newline='') as f:
        writer = csv.writer(f)
        for p, sup in mdfp_pats.items():
            pattern_str = '[' + ', '.join(format_item(id2item[i]) for i in p) + ']'
            writer.writerow([t0, t1, pattern_str, sup])

    # Export closed patterns (sd) with support
    with open('closed_patterns_no_label.csv', 'a', newline='') as f:
        writer = csv.writer(f)
        for p, sup in closed.items():
            pattern_str = '{' + ', '.join(format_item(id2item[i]) for i in p) + '}'
            writer.writerow([t0, t1, pattern_str, sup])

    # Export association rules with full columns
    with open('association_rules_no_label.csv', 'a', newline='') as f:
        writer = csv.writer(f)
        for A, b, supAB, conf, lift in rules:
            ants = '{' + ', '.join(format_item(id2item[i]) for i in A) + '}'
            cons = format_item(id2item[b])
            writer.writerow([t0, t1, ants, cons, supAB, f"{conf:.2f}", f"{lift:.2f}"])

    print(f"[Window {idx}] CSV update done.")

print("\n[Process] All windows processed. CSV files are ready.")
# Out:
# [CSV] Initialized CSV files.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 22
#      20 # Генерируем окна
#      21 windows = []
# ---> 22 cur = df['Timestamp'].min()
#      23 end = df['Timestamp'].max()
#      24 while cur + window_size <= end:
#
# NameError: name 'df' is not defined
